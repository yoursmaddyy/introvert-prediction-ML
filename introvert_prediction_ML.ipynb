# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-a624d276-fa19-475c-bb54-43d9d2c43395" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a624d276-fa19-475c-bb54-43d9d2c43395">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (18524, 9)

# %%
df.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone             float64
# Stage_fear                    object
# Social_event_attendance      float64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      17334.000000             17344.000000   17058.000000
# mean    9261.500000          3.137764                 5.265106       4.044319
# std     5347.562529          3.003786                 2.753359       2.062580
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          2.000000                 5.000000       4.000000
# 75%    13892.250000          4.000000                 8.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         17470.000000    17260.000000
# mean              7.996737        4.982097
# std               4.223484        2.879139
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Time_spent_Alone"].isna().sum()
# Out:
# np.int64(1190)

# %%
df["Time_spent_Alone"].value_counts()
# Out:
# Time_spent_Alone
# 0.0     3139
# 3.0     3081
# 2.0     3039
# 1.0     2973
# 4.0     1079
# 5.0      633
# 10.0     587
# 8.0      582
# 7.0      581
# 6.0      574
# 9.0      574
# 11.0     492
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      17334.000000             17344.000000   17058.000000
# mean    9261.500000          3.137764                 5.265106       4.044319
# std     5347.562529          3.003786                 2.753359       2.062580
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          2.000000                 5.000000       4.000000
# 75%    13892.250000          4.000000                 8.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         17470.000000    17260.000000
# mean              7.996737        4.982097
# std               4.223484        2.879139
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
df["Time_spent_Alone"] = df["Time_spent_Alone"].fillna(df["Time_spent_Alone"].mean())

# %%
df["Time_spent_Alone"].sample(20)
# Out:
# 587      3.000000
# 354      3.137764
# 1881     2.000000
# 14083    0.000000
# 6846     2.000000
# 8628     1.000000
# 4112     1.000000
# 10483    6.000000
# 17559    8.000000
# 17186    1.000000
# 8460     1.000000
# 13661    1.000000
# 1961     2.000000
# 6076     1.000000
# 6270     1.000000
# 15020    0.000000
# 8379     2.000000
# 13851    4.000000
# 3699     0.000000
# 10090    5.000000
# Name: Time_spent_Alone, dtype: float64

# %%
df["Time_spent_Alone"] = df["Time_spent_Alone"].astype("int")

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone               int64
# Stage_fear                    object
# Social_event_attendance      float64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df["Stage_fear"].value_counts()
# Out:
# Stage_fear
# No     12609
# Yes     4022
# Name: count, dtype: int64

# %%
df["Stage_fear"] = df["Stage_fear"].fillna("No")

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone               int64
# Stage_fear                    object
# Social_event_attendance      float64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                      0
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df["Social_event_attendance"].value_counts()
# Out:
# Social_event_attendance
# 4.0     2073
# 9.0     2063
# 7.0     2031
# 5.0     1985
# 6.0     1984
# 8.0     1945
# 3.0     1703
# 2.0     1063
# 0.0     1055
# 1.0      978
# 10.0     464
# Name: count, dtype: int64

# %%
df["Social_event_attendance"] = df["Social_event_attendance"].fillna(df["Social_event_attendance"].mean()).astype("int")

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone               int64
# Stage_fear                    object
# Social_event_attendance        int64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df["Going_outside"].isnull().sum()
# Out:
# np.int64(1466)

# %%
df["Going_outside"].mean()
# Out:
# np.float64(4.044319380935631)

# %%
df["Going_outside"] = df["Going_outside"].fillna(4).astype("int")

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone               int64
# Stage_fear                    object
# Social_event_attendance        int64
# Going_outside                  int64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                      0
# Social_event_attendance         0
# Going_outside                   0
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df['Drained_after_socializing'].value_counts()
# Out:
# Drained_after_socializing
# No     13313
# Yes     4062
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                      0
# Social_event_attendance         0
# Going_outside                   0
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df['Drained_after_socializing'].value_counts()
# Out:
# Drained_after_socializing
# No     13313
# Yes     4062
# Name: count, dtype: int64

# %%
df['Drained_after_socializing'] = df['Drained_after_socializing'].fillna("No")

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                      0
# Social_event_attendance         0
# Going_outside                   0
# Drained_after_socializing       0
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df['Friends_circle_size'] = df['Friends_circle_size'].fillna(df['Friends_circle_size'].mean()).astype("int")

# %%
df.dtypes
# Out:
# id                             int64
# Time_spent_Alone               int64
# Stage_fear                    object
# Social_event_attendance        int64
# Going_outside                  int64
# Drained_after_socializing     object
# Friends_circle_size            int64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df['Post_frequency'] = df['Post_frequency'].fillna(df['Post_frequency'].mean()).astype("int")

# %%
df.isna().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-09-23 20:45:32.959909&quot; name=date&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df.dtypes
# Out:
# id                            int64
# Time_spent_Alone              int64
# Stage_fear                   object
# Social_event_attendance       int64
# Going_outside                 int64
# Drained_after_socializing    object
# Friends_circle_size           int64
# Post_frequency                int64
# Personality                  object
# dtype: object

# %%
df.drop("id",inplace=True,axis=1)

# %%
df.dtypes
# Out:
# Time_spent_Alone              int64
# Stage_fear                   object
# Social_event_attendance       int64
# Going_outside                 int64
# Drained_after_socializing    object
# Friends_circle_size           int64
# Post_frequency                int64
# Personality                  object
# dtype: object

# %%
df["Stage_fear"]
# Out:
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4         No
#         ...
# 18519     No
# 18520     No
# 18521    Yes
# 18522    Yes
# 18523     No
# Name: Stage_fear, Length: 18524, dtype: object

# %%
df["Stage_fear"] = df["Stage_fear"].map({"Yes":1,"No":0})

# %%
df.dtypes
# Out:
# Time_spent_Alone              int64
# Stage_fear                    int64
# Social_event_attendance       int64
# Going_outside                 int64
# Drained_after_socializing    object
# Friends_circle_size           int64
# Post_frequency                int64
# Personality                  object
# dtype: object

# %%
df["Drained_after_socializing"] = df["Drained_after_socializing"].map({"Yes":1,"No":0})

# %%
df["Drained_after_socializing"].value_counts()
# Out:
# Drained_after_socializing
# 0    14462
# 1     4062
# Name: count, dtype: int64

# %%
df["Personality"]
# Out:
# 0        Extrovert
# 1        Extrovert
# 2        Introvert
# 3        Extrovert
# 4        Extrovert
#            ...
# 18519    Extrovert
# 18520    Extrovert
# 18521    Introvert
# 18522    Introvert
# 18523    Extrovert
# Name: Personality, Length: 18524, dtype: object

# %%
encoded_personality = pd.get_dummies(df["Personality"], drop_first=True)

# %%
encoded_personality
# Out:
#        Introvert
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
# ...          ...
# 18519      False
# 18520      False
# 18521       True
# 18522       True
# 18523      False
#
# [18524 rows x 1 columns]

# %%
df = pd.concat([df, encoded_personality], axis=1)

# %%
df
# Out:
#        Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                     0           0                        6              4
# 1                     1           0                        7              3
# 2                     6           1                        1              0
# 3                     3           0                        7              3
# 4                     1           0                        4              4
# ...                 ...         ...                      ...            ...
# 18519                 3           0                        7              3
# 18520                 1           0                        6              7
# 18521                 7           1                        1              1
# 18522                 3           1                        1              0
# 18523                 1           0                        8              6
#
# ...

# %%
#df.drop("Personality",axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0                  0           0                        6              4
# 1                  1           0                        7              3
# 2                  6           1                        1              0
# 3                  3           0                        7              3
# 4                  1           0                        4              4
# 5                  2           0                        8              5
# 6                  1           0                        8              4
# 7                  2           0                        8              3
# 8                  4           1                        2              1
# 9                  1           0                        8              6
# 10                 3           0                        7              4
# 11                 2           0                        6              3
# ...

# %%
df.drop("Personality",axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
X = df.drop("Introvert", axis=1)
Y = df["Introvert"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
model = LogisticRegression(max_iter=300)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=300)

# %%
Y_pred = model.predict(X_test)

# %%
print("Accuracy : ", accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy :  0.9678812415654521

# %%
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# Confusion Matrix:
#  [[2720   58]
#  [  61  866]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      2778
#         True       0.94      0.93      0.94       927
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.96      0.96      3705
# weighted avg       0.97      0.97      0.97      3705

# %%
from joblib import Parallel, delayed
import joblib


# Save the model as a pickle in a file
joblib.dump(model, 'introvert_model.pkl')

# %%
Y_test.shape
# Out:
# (3705,)
